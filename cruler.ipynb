# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = urlopen("https://en.wikipedia.org/wiki/List_of_Olympic_Games_host_cities")
soup = BeautifulSoup(url.read())
print(soup.find_all('tr'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-9546fa549b23> in <module>()
#       5 url = urlopen("https://en.wikipedia.org/wiki/List_of_Olympic_Games_host_cities")
#       6 soup = BeautifulSoup(url.read())
# ----> 7 print(soup.find_all('tr').find_all('td'))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1882     def __getattr__(self, key):
#    1883         raise AttributeError(
# -> 1884             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1885         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
import re

pattren = re.compile(r'\w\s\w\w')
result = pattran.findAll(i am)
print(result)
# Out:
#   File "<ipython-input-21-763514958e8d>", line 4
#     result = pattran.findAll(i am)
#                                 ^
# SyntaxError: invalid syntax

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import json
songs = []

url = urlopen("https://open.spotify.com/playlist/37i9dQZF1CyM2AQ7ZI19YJ")
soup = BeautifulSoup(url.read())

for tbl in soup.findAll('span', attrs={'class':re.compile("track-name")}):  
    song = {}
    for tr in tbl.find_all('tr')[1:]:
        songs = {}
        try:
            song["name"] = tr.th.a.get_text()
            song["href"] = tr.th.a['href']
            songs.append(song)
        except AttributeError:
            pass
        
print(songs)
# Out:
# []

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import json
songs = []

pattren = re.compile(r',"external_urls":{"spotify":"https:\/\/open.spotify.com\/track\/......................')


url = urlopen("https://open.spotify.com/playlist/3HtBlISXM86gijSJ3zp1C6")
soup = BeautifulSoup(url.read())

for song in soup.find_all('span', attrs={'class':re.compile("track-name")})[1:]:
    print(song)
# Out:
# <span class="track-name" dir="auto">Ultralight Beam</span>
# <span class="track-name" dir="auto">You Want It Darker</span>
# <span class="track-name" dir="auto">What It Means</span>
# <span class="track-name" dir="auto">Blessings</span>
# <span class="track-name" dir="auto">Black Beatles</span>
# <span class="track-name" dir="auto">Cranes in the Sky</span>
# <span class="track-name" dir="auto">Old Friends</span>
# <span class="track-name" dir="auto">Drone Bomb Me</span>
# <span class="track-name" dir="auto">Work from Home</span>
# <span class="track-name" dir="auto">Pink + White</span>
# <span class="track-name" dir="auto">I Can't Give Everything Away - Radio Edit</span>
# <span class="track-name" dir="auto">Rich</span>
# <span class="track-name" dir="auto">Work</span>
# <span class="track-name" dir="auto">Vincent</span>
# <span class="track-name" dir="auto">Come Down</span>
# <span class="track-name" dir="auto">Take Me To The Alley</span>
# ...

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import json
songs = []

pattern = re.compile(r'..external_urls..{.spotify.:.https:....open.spotify.com..track........................')
pattern2 = re.compile(r'https:......open.spotify.com...track.........................')


url = urlopen("https://open.spotify.com/playlist/3HtBlISXM86gijSJ3zp1C6")
soup = BeautifulSoup(url.read())

result = pattern.findall(str(soup))
result2 = pattern2.findall(str(result))

s = str(result2)
result3 = re.sub('[h]', 'a', s)

print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
import re
s = "Example String"
replaced = re.sub('[ES]', 'a', s)
print (replaced )

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import json
songs = []

pattern_url = re.compile(r'..external_urls..{.spotify.:.https:....open.spotify.com..track........................')
pattern_externallUrl = re.compile(r'https:......open.spotify.com...track.........................')
pattern3 = re.compile(r'popularity":...')


url_byYear = urlopen("https://open.spotify.com/playlist/3HtBlISXM86gijSJ3zp1C6")
soup = BeautifulSoup(url_byYear.read())

result = pattern_url.findall(str(soup))
result = pattern_externallUrl.findall(str(result))
result = re.sub('[\'\\\\\\\\]', '', str(result))
result = re.sub('[,]', ' ', result)
result = re.sub(r']', '\n', result)
result = re.sub(r'\[', '\n', result)
result = result.split()

p  = pattern3.findall(str(soup))
p2 = re.sub('[,]', '\n', str(p))


pattern_indexUrl = re.compile(r'<meta property="twitter:audio:artist_name" content="')
    
for index, elem in enumerate(result):
    url_byId = urlopen(elem)
    print(index, elem)

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import json


pattern_url = re.compile(r'..external_urls..{.spotify.:.https:....open.spotify.com..track........................')
pattern_externallUrl = re.compile(r'https:......open.spotify.com...track.........................')
pattern3 = re.compile(r'popularity":...')


url_byYear = urlopen("https://open.spotify.com/playlist/3HtBlISXM86gijSJ3zp1C6")
soup = BeautifulSoup(url_byYear.read())

result = pattern_url.findall(str(soup))
result = pattern_externallUrl.findall(str(result))
result = re.sub('[\'\\\\\\\\]', '', str(result))
result = re.sub('[,]', ' ', result)
result = re.sub(r']', '\n', result)
result = re.sub(r'\[', '\n', result)
result = result.split()

p  = pattern3.findall(str(soup))
p2 = re.sub('[,]', '\n', str(p))

pattern_indexUrl = re.compile(r'<meta property="twitter:audio:artist_name" content="..................................')
  
L = []
 
class SongObj:
    def __init__(self,artist, song):
        self.artist = artist
        self.song = song


data = [{}]
 
    
    
for index, elem in enumerate(result):
    url_byTrack = urlopen(elem)
    soup = BeautifulSoup(url_byTrack.read())
    track = soup.find_all('h1')
    track_item = str(track[0])    
    track_item = track_item[21:-12]
    artist_item = str(track[1])
    artist_item = artist_item[12:-5]
    so = SongObj(track_item,artist_item)
    L.insert(index,so)
    data.append({'index':index+1,'artist':artist_item,'song':track_item,'year':"2016"})

      
print (json.dumps(data))
# Out:
# [{}, {"index": 1, "artist": "Mitski", "song": "Your Best American Girl", "year": "2016"}, {"index": 2, "artist": "Kanye West", "song": "Ultralight Beam", "year": "2016"}, {"index": 3, "artist": "Leonard Cohen", "song": "You Want It Darker", "year": "2016"}, {"index": 4, "artist": "Drive-By Truckers", "song": "What It Means", "year": "2016"}, {"index": 5, "artist": "Drive-By Truckers", "song": "What It Means", "year": "2016"}, {"index": 6, "artist": "Chance the Rapper", "song": "Blessings", "year": "2016"}, {"index": 7, "artist": "Rae Sremmurd", "song": "Black Beatles", "year": "2016"}, {"index": 8, "artist": "Solange", "song": "Cranes in the Sky", "year": "2016"}, {"index": 9, "artist": "Pinegrove", "song": "Old Friends", "year": "2016"}, {"index": 10, "artist": "Pinegrove", "song": "Old Friends", "year": "2016"}, {"index": 11, "artist": "ANOHNI", "song": "Drone Bomb Me", "year": "2016"}, {"index": 12, "artist": "ANOHNI", "song": "Drone Bomb Me", "year": "2016"}, {"index": 13, "artis
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(client_id='39ac75394bcd4eb0a2ad340bd41a0f39',
                                                      client_secret='7a131b3539a944c7bb4e8906aee877ed')
spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)


results = spotify.search(q='artist:' + 'Drake', type='artist')
items = results['artists']['items']
if len(items) > 0:
    artist = items[0]
    print(items[0]['genres'])
# Out:
# ['canadian hip hop', 'canadian pop', 'hip hop', 'pop rap', 'rap']

# %%
import requests
import json
import re
import json
from watson_developer_cloud import ToneAnalyzerV3

tone_analyzer = ToneAnalyzerV3(
    version='2017-09-21',
    iam_apikey='{bYzmTXMpbUXPd6sxJPIZil1EqFSwkgPkfyl9wBxUafFk}',
    url='{https://gateway-lon.watsonplatform.net/tone-analyzer/api}'
)




url_lyrics = "https://api.musixmatch.com/ws/1.1/matcher.lyrics.get?q_track=Rae%20Sremmur&q_artist=Black Beatle&apikey=31a1860675cdd02bbef3b4032ee95a86"
response = json.loads(requests.get(url_lyrics).text)
result = str(response['message']['body']['lyrics']["lyrics_body"])
result = result[0:-70]
             
text = 'Team, I know that times are tough! Product '\
    'sales have been disappointing for the past three '\
    'quarters. We have a competitive product, but we '\
    'need to do a better job of selling it!'


tone_analysis = tone_analyzer.tone({'text': text},'application/json').get_result()

print(json.dumps(tone_analysis, indent=2))
# Out:
# ---------------------------------------------------------------------------
# WatsonApiException                        Traceback (most recent call last)
# <ipython-input-28-3af7db3dda0f> in <module>()
#      22
#      23
# ---> 24 tone_analysis = tone_analyzer.tone({'text': text},'application/json').get_result()
#      25
#      26 print(json.dumps(tone_analysis, indent=2))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\watson_developer_cloud\tone_analyzer_v3.py in tone(self, tone_input, content_type, sentences, tones, content_language, accept_language, **kwargs)
#     201             params=params,
#     202             data=data,
# --> 203             accept_json=True)
#     204         return response
#     205
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\watson_developer_cloud\watson_service.py in request(self, method, url, accept_json, headers, params, json, data, files, **kwargs)
#     436         auth = None
#     437         if self.token_manager:
# ...

# %%
import json


list_of_url_by_years = [{"link":"1wedGBMtddnGxpmBij5lUO","year":"2006"},
                        {"link":"22U6wJjyDlCYDzbJ6oIg3G","year":"2007"},
                        {"link":"5risns7vjPjRJjwdRlqVQa","year":"2008"},
                        {"link":"78nme2PFmjzWHgUelXerSm","year":"2009"},
                        {"link":"7fsFPe6ckDjWN673sk5Qzz","year":"2010"},
                        {"link":"42004WRNg430hY1cShpTsR","year":"2011"},
                        {"link":"3umOgg13I8RjiT3QCB6ogo","year":"2012"},
                        {"link":"2kDPYiTtUtm5eZUkVYJ4f0","year":"2013"},
                        {"link":"0KzjapF1zYpPYARZFeBnYm","year":"2014"},
                        {"link":"6MT7PxSJmrg8O31Z5vx1iJ","year":"2015"},
                        {"link":"3HtBlISXM86gijSJ3zp1C6","year":"2016"},
                        {"link":"37i9dQZF1DX5nwnRMcdReF","year":"2017"},
                        {"link":"4hOKQuZbraPDIfaGbM3lKI","year":"2018"}]

for index_elem,url_year in enumerate(list_of_url_by_years):
    print (url_year["link"])
# Out:
# 1wedGBMtddnGxpmBij5lUO
# 22U6wJjyDlCYDzbJ6oIg3G
# 5risns7vjPjRJjwdRlqVQa
# 78nme2PFmjzWHgUelXerSm
# 7fsFPe6ckDjWN673sk5Qzz
# 42004WRNg430hY1cShpTsR
# 3umOgg13I8RjiT3QCB6ogo
# 2kDPYiTtUtm5eZUkVYJ4f0
# 0KzjapF1zYpPYARZFeBnYm
# 6MT7PxSJmrg8O31Z5vx1iJ
# 3HtBlISXM86gijSJ3zp1C6
# 37i9dQZF1DX5nwnRMcdReF
# 4hOKQuZbraPDIfaGbM3lKI

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import json
import requests


pattern_url = re.compile(r'..external_urls..{.spotify.:.https:....open.spotify.com..track........................')
pattern_externallUrl = re.compile(r'https:......open.spotify.com...track.........................')
pattern3 = re.compile(r'popularity":...')


url_byYear = urlopen("https://open.spotify.com/playlist/3HtBlISXM86gijSJ3zp1C6")
soup = BeautifulSoup(url_byYear.read())

result = pattern_url.findall(str(soup))
result = pattern_externallUrl.findall(str(result))
result = re.sub('[\'\\\\\\\\]', '', str(result))
result = re.sub('[,]', ' ', result)
result = re.sub(r']', '\n', result)
result = re.sub(r'\[', '\n', result)
result = result.split()

p  = pattern3.findall(str(soup))
p2 = re.sub('[,]', '\n', str(p))

pattern_indexUrl = re.compile(r'<meta property="twitter:audio:artist_name" content="..................................')
  
L = []
 


api_key ='31a1860675cdd02bbef3b4032ee95a86'
data = [{}]
    
for index, elem in enumerate(result):
    url_byTrack = urlopen(elem)
    soup = BeautifulSoup(url_byTrack.read())
    track = soup.find_all('h1')
    track_item = str(track[0])    
    track_item = track_item[21:-12]
    artist_item = str(track[1])
    artist_item = artist_item[12:-5]
    url_lyrics = "https://api.musixmatch.com/ws/1.1/matcher.lyrics.get?q_track="+track_item+"&q_artist="+artist_item+"&apikey="+ api_key
    response = json.loads(requests.get(url_lyrics).text)
    
    if (response['message']['header']['status_code'] == 200):
        words = response['message']['body']['lyrics']["lyrics_body"]
        data.append({'index':index+1,'artist':artist_item,'song':track_item,'year':'2016','song_lyrics':words})
    else:
        data.append({'index':index+1,'artist':artist_item,'song':track_item,'year':'2016','song_lyrics':'none'})

      
print (json.dumps(data))
# Out:
# [{}, {"index": 1, "artist": "Mitski", "song": "Your Best American Girl", "year": "2016", "song_lyrics": "If I could, I'd be a little spoon\nAnd kiss your fingers forever more\nBut big spoon, you have so much to do\nAnd I have nothing ahead of me\nYou're the sun, you've never seen the night\nBut you hear its song from the morning birds\nBut I'm not the moon, I'm not even a star\nBut awake at night I'll be singing to the birds\n...\n\n******* This Lyrics is NOT for Commercial use *******\n(1409618110736)"}, {"index": 2, "artist": "Kanye West", "song": "Ultralight Beam", "year": "2016", "song_lyrics": "Yes, God)\nWe don't want no devils in the house, God (Yes, Lord)\nWe want the lord (Yes, Jesus)\nAnd that's it (Yes, God)\nHallej- hand over Satan (Yes, Jesus)\nJesus praise the Lord (Yes God)\nHallelujah, God (Yes, God)\nWe don't want no devils in the house, God (Yes, Lord)\nWe want the lord (Yes, Jesus)\nAnd that's it (Yes, God)\nHallej- hand over Satan (Yes, Jesus)\nJesus praise the Lo
# ...

# %%
import json
from watson_developer_cloud import ToneAnalyzerV3

tone_analyzer = ToneAnalyzerV3(
    version='2017-09-21',
    iam_apikey='bYzmTXMpbUXPd6sxJPIZil1EqFSwkgPkfyl9wBxUafFk',
    url='https://gateway-lon.watsonplatform.net/tone-analyzer/api'
)

text = "He was running down the street\nWhen they shot him in his tracks\nAbout the only thing agreed upon\n\nIs he ain't coming back\nThere won't be any trial\nSo the air it won't be cleared\nThere's just two sides calling names\nOut of anger out of fear\nIf you say it wasn't racial\nWhen they shot him in his tracks\nWell I guess that means that you ain't black\nIt means that you ain't black\nI mean Barack Obama won\nAnd you can choose where to eat\nBut you don't see too many white kids\nLying bleeding on the street\n\nIn some town in Missouri\nBut it could be anywhere\n\nIt could be right here on Ruth Street\nIn fact it's happened here\nAnd it happened where you're sitting\nWherever that might be\nAnd it happened last weekend\nAnd it will happen again next week\nAnd when they turned him over"

tone_analysis = tone_analyzer.tone(
    {'text': text},
    'application/json'
).get_result()
print(json.dumps(tone_analysis['document_tone']['tones'][0]['tone_name']))
# Out:
# ---------------------------------------------------------------------------
# WatsonApiException                        Traceback (most recent call last)
# <ipython-input-1-a0fd3c3517d6> in <module>()
#      12 tone_analysis = tone_analyzer.tone(
#      13     {'text': text},
# ---> 14     'application/json'
#      15 ).get_result()
#      16 print(json.dumps(tone_analysis['document_tone']['tones'][0]['tone_name']))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\watson_developer_cloud\tone_analyzer_v3.py in tone(self, tone_input, content_type, sentences, tones, content_language, accept_language, **kwargs)
#     201             params=params,
#     202             data=data,
# --> 203             accept_json=True)
#     204         return response
#     205
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\watson_developer_cloud\watson_service.py in request(self, method, url, accept_json, headers, params, json, data, files, **kwargs)
# ...

# %%
import requests
response = requests.get("https://qemotion.p.mashape.com/v1/emotional_analysis/get_emotions",
  headers={
    "X-Mashape-Key": "EumaNWwAzQmshvvOk8Nuyzyx9yD7p1PHWcfjsnmSL3jUT8bd6t",
    "Authorization": "Token token=bc55ca0a8f5c8c41556f499a93f7077a",
    "Content-Type": "application/json; charset=UTF-8",
    "lang": "en",
    "text": "What a beautiful day today!",
    "Accept": "text/plain"
  }
)
print (response)
# Out:
# <Response [403]>

# %%
# Out:
#   File "<ipython-input-16-549c5e01d45f>", line 1
#     curl --get --include 'https://qemotion.p.mashape.com/v1/emotional_analysis/get_emotions'   -H 'X-Mashape-Key: EumaNWwAzQmshvvOk8Nuyzyx9yD7p1PHWcfjsnmSL3jUT8bd6t'   -H 'Authorization: Token token="bc55ca0a8f5c8c41556f499a93f7077a"'   -H 'Content-Type: application/json; charset=UTF-8'   -H 'lang: en'   -H 'text: What a beautiful day today!'   -H 'Accept: text/plain'
#                                                                                            ^
# SyntaxError: invalid syntax

# %%
import json

absolute_json_file_path = "C:\\Users\\Yarin\\Documents\\Python Scripts\\list_20181229.json"

with open(absolute_json_file_path, encoding='utf-8-sig') as json_file:
    json_data = json.load(json_file)
    print(json_data)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
